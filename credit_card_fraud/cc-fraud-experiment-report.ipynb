# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
#Load datasets

xgboost_df = pd.read_csv("./results/xgboost/cc-fraud-xgboost-report.csv")
lightgbm_df = pd.read_csv("./results/lightgbm/cc-fraud-lightgbm-report.csv")
catboost_df = pd.read_csv("./results/catboost/cc-fraud-catboost-report.csv")
random_forest_df = pd.read_csv("./results/random-forest/cc-fraud-random-forest-report.csv")

# %%
def plot_accuracy_chart():
    xgboost = xgboost_df['Accuracy'].tolist() # list(map(lambda x: x * 100, xgboost_df['Accuracy'].tolist())
    lightgbm = lightgbm_df['Accuracy'].tolist()
    catboost = catboost_df['Accuracy'].tolist()
    random_forest = random_forest_df['Accuracy'].tolist()
    
    plt.plot(list(range(1,(len(xgboost) + 1))), xgboost, label = "XGBoost")
    plt.plot(list(range(1,(len(lightgbm) + 1))), lightgbm, label = "LightGBM")
    plt.plot(list(range(1,(len(catboost) + 1))), catboost, label = "Catboost")
    plt.plot(list(range(1,(len(random_forest) + 1))), random_forest, label = "Random Forest")
    
    plt.xlabel("Number of features")
    plt.ylabel("Accuracy (%)")  
    plt.legend()

    plt.savefig('./results/final-report/cc-fraud-accuracy.png')
             

plot_accuracy_chart()

# %%
def plot_precision_chart():
    xgboost = xgboost_df['Precision'].tolist() # list(map(lambda x: x * 100, xgboost_df['Accuracy'].tolist())
    lightgbm = lightgbm_df['Precision'].tolist()
    catboost = catboost_df['Precision'].tolist()
    random_forest = random_forest_df['Precision'].tolist()
    
    plt.plot(list(range(1,(len(xgboost) + 1))), xgboost, label = "XGBoost")
    plt.plot(list(range(1,(len(lightgbm) + 1))), lightgbm, label = "LightGBM")
    plt.plot(list(range(1,(len(catboost) + 1))), catboost, label = "Catboost")
    plt.plot(list(range(1,(len(random_forest) + 1))), random_forest, label = "Random Forest")
    
    plt.xlabel("Number of features")
    plt.ylabel("Precision (%)")  
    plt.legend()

    plt.savefig('./results/final-report/cc-fraud-precision.png')
             

plot_precision_chart()

# %%
def plot_recall_chart():
    xgboost = xgboost_df['Recall'].tolist() # list(map(lambda x: x * 100, xgboost_df['Accuracy'].tolist())
    lightgbm = lightgbm_df['Recall'].tolist()
    catboost = catboost_df['Recall'].tolist()
    random_forest = random_forest_df['Recall'].tolist()
    
    plt.plot(list(range(1,(len(xgboost) + 1))), xgboost, label = "XGBoost")
    plt.plot(list(range(1,(len(lightgbm) + 1))), lightgbm, label = "LightGBM")
    plt.plot(list(range(1,(len(catboost) + 1))), catboost, label = "Catboost")
    plt.plot(list(range(1,(len(random_forest) + 1))), random_forest, label = "Random Forest")
    
    plt.xlabel("Number of features")
    plt.ylabel("Recall (%)")  
    plt.legend()

    plt.savefig('./results/final-report/cc-fraud-recall.png')
             

plot_recall_chart()

# %%
def plot_f1_score_chart():
    xgboost = xgboost_df['F1 Score'].tolist() # list(map(lambda x: x * 100, xgboost_df['Accuracy'].tolist())
    lightgbm = lightgbm_df['F1 Score'].tolist()
    catboost = catboost_df['F1 Score'].tolist()
    random_forest = random_forest_df['F1 Score'].tolist()
    
    plt.plot(list(range(1,(len(xgboost) + 1))), xgboost, label = "XGBoost")
    plt.plot(list(range(1,(len(lightgbm) + 1))), lightgbm, label = "LightGBM")
    plt.plot(list(range(1,(len(catboost) + 1))), catboost, label = "Catboost")
    plt.plot(list(range(1,(len(random_forest) + 1))), random_forest, label = "Random Forest")
    
    plt.xlabel("Number of features")
    plt.ylabel("F1 Score (%)")  
    plt.legend()

    plt.savefig('./results/final-report/cc-fraud-f1-score.png')
             

plot_f1_score_chart()

# %%
def plot_training_time_chart():
    xgboost = xgboost_df['Training Time'].tolist() # list(map(lambda x: x * 100, xgboost_df['Accuracy'].tolist())
    lightgbm = lightgbm_df['Training Time'].tolist()
    catboost = catboost_df['Training Time'].tolist()
    random_forest = random_forest_df['Training Time'].tolist()
    
    plt.plot(list(range(1,(len(xgboost) + 1))), xgboost, label = "XGBoost")
    plt.plot(list(range(1,(len(lightgbm) + 1))), lightgbm, label = "LightGBM")
    plt.plot(list(range(1,(len(catboost) + 1))), catboost, label = "Catboost")
    plt.plot(list(range(1,(len(random_forest) + 1))), random_forest, label = "Random Forest")
    
    plt.xlabel("Number of features")
    plt.ylabel("Time (ms)")  
    plt.legend()
    
    plt.savefig('./results/final-report/cc-fraud-time.png')
             

plot_training_time_chart()

# %%
def plot_storage():
    xgboost = xgboost_df['Storage'].tolist() # list(map(lambda x: x * 100, xgboost_df['Accuracy'].tolist())
    lightgbm = lightgbm_df['Storage'].tolist()
    catboost = catboost_df['Storage'].tolist()
    random_forest = random_forest_df['Storage'].tolist()
    
    plt.plot(list(range(1,(len(xgboost) + 1))), xgboost, label = "XGBoost")
    plt.plot(list(range(1,(len(lightgbm) + 1))), lightgbm, label = "LightGBM")
    plt.plot(list(range(1,(len(catboost) + 1))), catboost, label = "Catboost")
    plt.plot(list(range(1,(len(random_forest) + 1))), random_forest, label = "Random Forest")
    
    plt.xlabel("Number of features")
    plt.ylabel("Storage (bytes)")  
    plt.legend()
    
    plt.savefig('./results/final-report/cc-fraud-storage.png')
             

plot_storage()

# %%
xgboost_df = pd.read_csv("./results/xgboost/cc-fraud-shap-xgboost.csv")
xgboost_data = xgboost_df['feature_name'].tolist()

lightgbm_df = pd.read_csv("./results/lightgbm/cc-fraud-shap-lightgbm.csv")
lightgbm_data = lightgbm_df['feature_name'].tolist()

random_forest_df = pd.read_csv("./results/random-forest/cc-fraud-shap-random-forest.csv")
random_forest_data = random_forest_df['feature_name'].tolist()

catboost_df = pd.read_csv("./results/catboost/cc-fraud-shap-catboost.csv")
catboost_data = random_forest_df['feature_name'].tolist()

data = {
        'XGBoost': xgboost_data,
        'LightGBM': lightgbm_data,
        'Random Forest': random_forest_data,
        'Catboost': catboost_data 
       }

df = pd.DataFrame (data, columns = ['Random Forest', 'XGBoost', 'Catboost', 'LightGBM'])
df.to_csv('./results/final-report/cc-fraud-feature-relevance.csv')
print(df.to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
# {} & Random Forest & XGBoost & Catboost & LightGBM \\
# \midrule
# 0  &           V14 &     V14 &      V14 &       V1 \\
# 1  &           V17 &      V4 &      V17 &      V12 \\
# 2  &           V12 &     V12 &      V12 &      V26 \\
# 3  &            V4 &  Amount &       V4 &      V14 \\
# 4  &           V10 &     V10 &      V10 &      V16 \\
# 5  &            V1 &     V11 &       V1 &      V20 \\
# 6  &           V11 &     V19 &      V11 &       V5 \\
# 7  &            V2 &     V20 &       V2 &      V15 \\
# 8  &           V16 &      V3 &      V16 &       V3 \\
# 9  &            V3 &     V22 &       V3 &       V7 \\
# 10 &            V7 &     V16 &       V7 &      V13 \\
# 11 &        Amount &      V8 &   Amount &      V22 \\
# 12 &           V19 &      V7 &      V19 &      V10 \\
# 13 &            V9 &      V5 &       V9 &      V18 \\
# 14 &           V20 &     V13 &      V20 &       V9 \\
# 15 &           V18 &    Time &      V18 &       V8 \\
# 16 &           V21 &     V25 &      V21 &      V17 \\
# 17 &           V26 &     V26 &      V26 &      V21 \\
# 18 &          Time &     V28 &     Time &      V28 \\
# 19 &           V13 &      V2 &      V13 &      V23 \\
# 20 &            V6 &     V21 &       V6 &       V4 \\
# 21 &           V15 &     V24 &      V15 &     Time \\
# 22 &            V8 &      V6 &       V8 &      V27 \\
# 23 &           V23 &      V1 &      V23 &      V24 \\
# 24 &           V28 &     V15 &      V28 &      V25 \\
# 25 &           V25 &      V9 &      V25 &      V11 \\
# 26 &           V27 &     V23 &      V27 &      V19 \\
# 27 &            V5 &     V18 &       V5 &   Amount \\
# 28 &           V24 &     V17 &      V24 &       V2 \\
# 29 &           V22 &     V27 &      V22 &       V6 \\
# \bottomrule
# \end{tabular}
